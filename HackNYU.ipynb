# %%
# !pip install flask_assistant
# Out:
# ...
#     100% |████████████████████████████████| 40kB 4.5MB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 256kB 1.5MB/s ta 0:00:01
# ...

# %%
# !mkdir my_assistant

# %%
# !cd my_assistant

# %%
# !touch webhook.py

# %%
# !pip install ngrok
# Out:
# ...
#   Stored in directory: /Users/nissani/Library/Caches/pip/wheels/7c/e5/bb/0aba6d734b1363ac037c3806ba9c5af55cc0f5f6d711153813
# Successfully built ngrok
# ...

# %%
# !brew cask install ngrok
# Out:
# Updating Homebrew...
# ==> Auto-updated Homebrew!
# Updated 3 taps (homebrew/cask-versions, homebrew/core and homebrew/cask).
# ==> New Formulae
# ahoy                       gtranslator                protoc-gen-go
# anycable-go                hexyl                      qalculate-gtk
# anyenv                     i386-elf-gdb               rakudo
# aom                        interactive-rebase-tool    rargs
# astrometry-net             istioctl                   react-native-cli
# atomist-cli                jinja2-cli                 redis@4.0
# aws-iam-authenticator      jmxterm                    ruby@2.5
# bluetoothconnector         jp                         s3ql
# bumpversion                kubeprod                   sha3sum
# cassandra-reaper           kubeseal                   ship
# chafa                      kubespy                    signal-cli
# cmusfm                     libgusb                    simple-scan
# cryptominisat              libkeccak                  sloc
# ...

# %%
# !ngrok http 5000
# Out:
# 7=ngrok by @inconshreveable                                       (Ctrl+C to quit)                                                                                Session Status                connecting                                        Version                       2.2.8                                             Region                        United States (us)                                Web Interface                 http://127.0.0.1:4040                                                                                                             Connections                   ttl     opn     rt1     rt5     p50     p90                                     0       0       0.00    0.00    0.00    0.00                                                                                                                                                                                                                                                                                          
# ...

# %%
# !pip install selenium

# %%
from selenium import webdriver

driver = webdriver.Chrome(executable_path = '/Users/nissani/Desktop/chromedriver')
driver.get("https://www.twilio.com/labs/twimlets/echo")
driver.find_element_by_tag_name("textarea").send_keys("This is the input text which is inputed.")
